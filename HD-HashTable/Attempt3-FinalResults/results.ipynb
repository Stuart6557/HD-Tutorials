# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Number of Reads

# %%
num_reads = [30, 40, 50, 100, 150, 200]
total_accuracy = [88.16, 85.75, 85.75, 79.50, 74.57, 72.50]

plt.scatter(num_reads, total_accuracy, color='blue', marker='o', label='Overall Accuracy')
plt.title('Number of Reads in Dataset vs. Overall Accuracy')
plt.xlabel('Number of Reads')
plt.ylabel('Overall Accuracy')
plt.grid(True)
plt.legend()

plt.show()

# %%
num_reads = [30, 40, 50, 100, 150, 200]
sensitivity = [87.78, 84.00, 85.50, 87.00, 91.33, 88.50]

# Sensitivity is also known as recall or true positive rate
plt.scatter(num_reads, sensitivity, color='blue', marker='o', label='Sensitivity')
plt.title('Number of Reads in Dataset vs. Sensitivity')
plt.xlabel('Number of Reads')
plt.ylabel('Sensitivity')
plt.grid(True)
plt.legend()

plt.show()

# %%
# Data
num_reads = [30, 40, 50, 100, 150, 200]
specificity = [88.50, 87.50, 86.00, 72.00, 62.00, 56.50]

# Specificity is also known as true negative rate
plt.scatter(num_reads, specificity, color='blue', marker='o', label='Specificity')
plt.title('Number of Reads in Dataset vs. Specificity')
plt.xlabel('Number of Reads')
plt.ylabel('Specificity')
plt.grid(True)
plt.legend()

plt.show()

# %% [markdown]
# ### K-mer Length

# %%
k = [501, 1001, 2001, 3001, 4001]
total_accuracy = [86.32, 90.26, 87.11, 89.21, 90.00]

plt.scatter(k, total_accuracy, color='blue', marker='o', label='Overall Accuracy')
plt.title('K-mer Length vs. Overall Accuracy')
plt.xlabel('K')
plt.ylabel('Overall Accuracy')
plt.grid(True)
plt.legend()
plt.ylim(0, 100)

plt.show()

# %%
k = [501, 1001, 2001, 3001, 4001]
sensitivity = [83.89, 83.89, 82.22, 85.56, 84.44]

plt.scatter(k, sensitivity, color='blue', marker='o', label='Sensitivity')
plt.title('K-mer Length vs. Sensitivity')
plt.xlabel('K')
plt.ylabel('Sensitivity')
plt.grid(True)
plt.legend()
plt.ylim(0, 100)

plt.show()

# %%
k = [501, 1001, 2001, 3001, 4001]
specificity = [88.50, 96.00, 91.50, 92.50, 95.00]

plt.scatter(k, specificity, color='blue', marker='o', label='Specificity')
plt.title('K-mer Length vs. Specificity')
plt.xlabel('K')
plt.ylabel('Specificity')
plt.grid(True)
plt.legend()
plt.ylim(0, 100)

plt.show()
